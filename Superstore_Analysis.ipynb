# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("superstore.csv", encoding="latin1")

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
print(df.shape)

print(df.columns.tolist())

print(df.isnull().sum())

df.drop_duplicates()
# Out:
# (9994, 21)
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit']
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# %%
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month_name()
df['Month_Num'] = df['Order Date'].dt.month

# %%
# total sales
print(round(df["Sales"].sum(),2))
# Out:
# 2297200.86

# %%
# total profit
print(round(df["Profit"].sum(),2))
# Out:
# 286397.02

# %%
#  sales by region

sales_region = df.groupby("Region")["Sales"].sum()
bars = sns.barplot(
    x = sales_region.index,
    y = sales_region.values,
    color = "green",
    ec = "black"
            )
plt.title("Sales by Region",fontweight="bold",color="red")
plt.grid()
plt.tight_layout
plt.savefig("../images/sales_by_region.png")
plt.show()

# %%
# category analysis
ca = df.groupby("Category")["Profit"].sum()
sns.barplot(
    x = ca.index,
    y = ca.values
)
plt.title("Profit by Category",color="maroon")

plt.savefig("../images/profit_by_category.png")

# %%
# sub-category analysis

sca = df.groupby("Sub-Category")[["Profit"]].sum()
print(sca)
# Out:
#                   Profit
# Sub-Category
# Accessories   41936.6357
# Appliances    18138.0054
# Art            6527.7870
# Binders       30221.7633
# Bookcases     -3472.5560
# Chairs        26590.1663
# Copiers       55617.8249
# Envelopes      6964.1767
# Fasteners       949.5182
# Furnishings   13059.1436
# Labels         5546.2540
# Machines       3384.7569
# Paper         34053.5693
# Phones        44515.7306
# Storage       21278.8264
# Supplies      -1189.0995
# Tables       -17725.4811

# %%
# Discount Impact

sns.scatterplot(
    data = df,
    x = "Discount",
    y = "Profit"
)

plt.title("Discount Impact on Profit",fontweight = "bold" ,color="red")
plt.savefig("../images/discount_imapct_on_profit.png")

# %%
# Monthly Sales Trend

monthly = (
    df.groupby(df["Order Date"].dt.to_period("M"))["Sales"]
    .sum()
    .reset_index()
)

monthly["Order Date"] = monthly["Order Date"].astype(str)

sns.lineplot(
    data=monthly,
    x="Order Date",
    y="Sales"
)

plt.xticks(
    ticks=range(0, len(monthly), 3),
    rotation=45
)

plt.title("Montly Sales Trend")
plt.tight_layout()
plt.savefig("../images/monthly_sales_trend.png")

plt.show()

# %%
# Top - 10 customers
top_10_customers = df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(10)
top_10_customers
# Out:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
# Shipping Analysis
df['Shipping Days'] = (
    df['Ship Date'] -
    df['Order Date']
).dt.days
